# %% [markdown]
# Import the required packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import keras
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# Read the customer information  from the bank database and print some sample rows.

# %%
data = pd.read_csv('bank_database.csv')
print("Data base")
data
# Out:
# Data base
#       RowNumber  CustomerId         Surname  CreditScore Geography  Gender  \
# 0             1    15634602        Hargrave          619    France  Female
# 1             2    15647311            Hill          608     Spain  Female
# 2             3    15619304            Onio          502    France  Female
# 3             4    15701354            Boni          699    France  Female
# 4             5    15737888        Mitchell          850     Spain  Female
# 5             6    15574012             Chu          645     Spain    Male
# 6             7    15592531        Bartlett          822    France    Male
# 7             8    15656148          Obinna          376   Germany  Female
# 8             9    15792365              He          501    France    Male
# 9            10    15592389              H?          684    France    Male
# 10           11    15767821          Bearce          528    France    Male
# ...

# %% [markdown]
# RowNumber, CustomerId, Surname are irrelevent columns so let us ignore them while loading the input feature verctors X

# %%
X = data.iloc[:,3:13].values
y = data.iloc[:,13].values
X
# Out:
# array([[619, 'France', 'Female', ..., 1, 1, 101348.88],
#        [608, 'Spain', 'Female', ..., 0, 1, 112542.58],
#        [502, 'France', 'Female', ..., 1, 0, 113931.57],
#        ...,
#        [709, 'France', 'Female', ..., 0, 1, 42085.58],
#        [772, 'Germany', 'Male', ..., 1, 0, 92888.52],
#        [792, 'France', 'Female', ..., 1, 0, 38190.78]], dtype=object)

# %% [markdown]
# Encoding categorical data: Since it is difficult to work with country names and 'male', 'female' strings as our input feature vectors, let us encode them as categorical data.

# %%
label_encoder_country = LabelEncoder()
X[:,1] = label_encoder_country.fit_transform(X[:,1])
label_encoder_gender = LabelEncoder()
X[:,2] = label_encoder_gender.fit_transform(X[:,2])
X
# Out:
# array([[619, 0, 0, ..., 1, 1, 101348.88],
#        [608, 2, 0, ..., 0, 1, 112542.58],
#        [502, 0, 0, ..., 1, 0, 113931.57],
#        ...,
#        [709, 0, 0, ..., 0, 1, 42085.58],
#        [772, 1, 1, ..., 1, 0, 92888.52],
#        [792, 0, 0, ..., 1, 0, 38190.78]], dtype=object)

# %% [markdown]
# Note that the three countries are encoded as numbers 0,1 and 2. Let us now do a one hot encoding.

# %%
onehotencoder = OneHotEncoder(categorical_features=[1])
X = onehotencoder.fit_transform(X).toarray()
X = X[:,1:]

# %% [markdown]
# Splitting the dataset into training and test set

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state = 0)
#Do some feature scaling also to speed us everything
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %% [markdown]
# Initializing the Artificial Neural Network and training it with 80% data

# %%
ANN_classifier = Sequential()
# Adding the input layer and the first hidden layer
ANN_classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))
# Adding the second hidden layer
ANN_classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
# Adding the output layer
ANN_classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
# Compiling the ANN
ANN_classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
# Fitting the ANN to the Training set
history = ANN_classifier.fit(X_train, y_train, batch_size = 10, epochs = 10)
# Out:
# Epoch 1/10
# 8000/8000 [==============================] - 1s - loss: 0.4823 - acc: 0.7959
# Epoch 2/10
# 8000/8000 [==============================] - 0s - loss: 0.4266 - acc: 0.7960
# Epoch 3/10
# 8000/8000 [==============================] - 0s - loss: 0.4205 - acc: 0.8070
# Epoch 4/10
# 8000/8000 [==============================] - 0s - loss: 0.4173 - acc: 0.8246
# Epoch 5/10
# 8000/8000 [==============================] - 0s - loss: 0.4151 - acc: 0.8281
# Epoch 6/10
# 8000/8000 [==============================] - 0s - loss: 0.4137 - acc: 0.8286
# Epoch 7/10
# 8000/8000 [==============================] - 0s - loss: 0.4122 - acc: 0.8314
# Epoch 8/10
# 8000/8000 [==============================] - 0s - loss: 0.4109 - acc: 0.8321
# Epoch 9/10
# 8000/8000 [==============================] - 0s - loss: 0.4101 - acc: 0.8329
# Epoch 10/10
# 8000/8000 [==============================] - 0s - loss: 0.4094 - acc: 0.8334

# %%
#df = pd.DataFrame.from_csv('bank_database.csv', header=0, sep=',', index_col=0, infer_datetime_format=False)
#df.groupby('Geography').Age.plot()
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'acc'])

# %%
# Predicting the Test set results
y_pred = ANN_classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
#Let us predict if a particular customer will leave the bank
m,n=X.shape
X_particular = np.zeros((1,n))
X_particular[0,0]=0
X_particular[0,1]=0
X_particular[0,2]=600
X_particular[0,3]=1
X_particular[0,4]=40
X_particular[0,5]=3
X_particular[0,6]=60000
X_particular[0,7]=2
X_particular[0,8]=1
X_particular[0,9]=1
X_particular[0,10]=50000

# %%
y_pred = ANN_classifier.predict(sc.transform(X_particular))
y_pred = y_pred >0.5

# %%
y_pred
# Out:
# array([[False]], dtype=bool)
